# %%
num = int(input("Enter the number  : "))
if num > 0 :
  print("positive")
elif num < 0 :
  print("Negative")
else :
  print("zero")
# Out:
# Enter the number  : 20
# positive

# %%
a = int(input("enter the a  :"))
b = int(input("enter the b  :"))
c = int(input("enter the c  :"))

if a >=b and a >=c:
  print("a is largest :",a)
elif b >=a and b >=c :
  print("b is larger :", b)
else:
  print("c is larger :",c)
# Out:
# enter the a  :5
# enter the b  :7
# enter the c  :1
# b is larger : 7

# %%
for i in range(1,6):
  print("interation :",i)
for i in range(10,0,-2):
  print(i)
# Out:
# interation : 1
# interation : 2
# interation : 3
# interation : 4
# interation : 5
# 10
# 8
# 6
# 4
# 2

# %%
count =1
while count <= 5:
  print("count is ",count)
  count +=1

for i in range(1,11):
  if i == 6:
    break
  print(i)
# Out:
# count is  1
# count is  2
# count is  3
# count is  4
# count is  5
# 1
# 2
# 3
# 4
# 5

# %%
n = int(input("enter the number  :"))
for i in range(1,11):
  print(f"{n} x {i} = {n*i}")
# Out:
# enter the number  :2
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 2 x 9 = 18
# 2 x 10 = 20

# %%
def greet(name):
  print(f"hello , {name} ! wellcome to python")
greet("alice")
greet("Bob")
# Out:
# hello , alice ! wellcome to python
# hello , Bob ! wellcome to python

# %%
def add(a,b):
  return a+b
def power(base,exponent=2):
  return base ** exponent

print(add(10,20))
print(power(5))
print(power(5,3))
# Out:
# 30
# 25
# 125

# %%
print("PART B- Practice Exerises")
# Out:
# PART B- Practice Exerises

# %%
num = int(input("Enter a number: "))

if num % 2 == 0:
    print("Even number")
else:
    print("Odd number")
# Out:
# Enter a number: 50
# Even number

# %%
marks = int(input("Enter student's marks: "))

if marks >= 90:
    print("Grade: A")
elif marks >= 75:
    print("Grade: B")
elif marks >= 60:
    print("Grade: C")
elif marks >= 40:
    print("Grade: D")
else:
    print("Grade: F")
# Out:
# Enter student's marks: 60
# Grade: C

# %%
for i in range(1, 101):
    if i % 3 == 0 and i % 5 == 0:
        print(i)
# Out:
# 15
# 30
# 45
# 60
# 75
# 90

# %%
num = int(input("Enter a number: "))

sum = 0

while num > 0:
    digit = num % 10
    sum = sum + digit
    num = num // 10

print("Sum of digits:", sum)
# Out:
# Enter a number: 560
# Sum of digits: 11

# %%
num = int(input("Enter a number: "))

if num <= 1:
    print("Not a prime number")
else:
    prime = True

    for i in range(2, num):
        if num % i == 0:
            prime = False
            break

    if prime:
        print("Prime number")
    else:
        print("Not a prime number")
# Out:
# Enter a number: 11
# Prime number

# %%
def is_even(n):
    if n % 2 == 0:
        return True
    else:
        return False


# Testing
numbers = [2, 5, 10, 13, 20]

for num in numbers:
    print(num, "->", is_even(num))
# Out:
# 2 -> True
# 5 -> False
# 10 -> True
# 13 -> False
# 20 -> True

# %%
def factorial(n):
    result = 1

    for i in range(1, n + 1):
        result = result * i

    return result


# Testing
num = int(input("Enter a number: "))

print("Factorial:", factorial(num))
# Out:
# Enter a number: 6
# Factorial: 720
