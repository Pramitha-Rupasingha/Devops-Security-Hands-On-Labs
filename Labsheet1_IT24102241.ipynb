# %%
print("Hello, World")
print("Wellcome to python programming")
# Out:
# Hello, World
# Wellcome to python programming

# %%
name = "Alice"
age = 20
height = 5.4
is_student = True

print(name, age, height, is_student)
print(type(name) , type(age) , type(height) , type(is_student))
# Out:
# Alice 20 5.4 True
# <class 'str'> <class 'int'> <class 'float'> <class 'bool'>

# %%
user_name = input("Enter the your name :")
user_age = int(input("Enter the age    :"))
print("Hello" , user_name , ". you are ", user_age, "years old")
# Out:
# Enter the your name :arosha
# Enter the age    :22
# Hello arosha . you are  22 years old

# %%
a = 15
b = 4
print("addition :" , a + b)
print("subtraction :", a - b)
print("multiplication :", a * b)
print("division :", a / b )
print("floor division :", a // b)
print("modulus :", a % b)
print("exponent :", a ** b)
# Out:
# addition : 19
# subtraction : 11
# multiplication : 60
# division : 3.75
# floor division : 3
# modulus : 3
# exponent : 50625

# %%
x = 10
y = 20
print(x > y, x < y, x == y, x != y)
print(x < 15 and y > 15)
print(x > 15 or y > 15)

num_str = "100"
num_int = int(num_str)
print(num_int + 50)
# Out:
# False True False True
# True
# True
# 150

# %%
name = "Arosha Sampath"
roll_number = "IT24103938"
department = "Cyber Security"

print(f"My name is {name}, my roll number is {roll_number}, and my department is {department}.")
# Out:
# My name is Arosha Sampath, my roll number is IT24103938, and my department is Cyber Security.

# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

print("Sum =", num1 + num2)
print("Difference =", num1 - num2)
print("Product =", num1 * num2)
print("Quotient =", num1 / num2)
# Out:
# Enter first number: 10
# Enter second number: 20
# Sum = 30.0
# Difference = -10.0
# Product = 200.0
# Quotient = 0.5

# %%
length = float(input("Enter length: "))
breadth = float(input("Enter breadth: "))

area = length * breadth
perimeter = 2 * (length + breadth)

print("Area =", area)
print("Perimeter =", perimeter)
# Out:
# Enter length: 20
# Enter breadth: 5
# Area = 100.0
# Perimeter = 50.0

# %%
celsius = float(input("Enter temperature in Celsius: "))

fahrenheit = (celsius * 9/5) + 32

print("Temperature in Fahrenheit =", fahrenheit)
# Out:
# Enter temperature in Celsius: 67
# Temperature in Fahrenheit = 152.6

# %%
radius = float(input("Enter radius: "))

pi = 3.14159

area = pi * radius * radius
circumference = 2 * pi * radius

print("Area =", area)
print("Circumference =", circumference)
# Out:
# Enter radius: 90
# Area = 25446.878999999997
# Circumference = 565.4861999999999

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

a, b = b, a

print("After swapping:")
print("a =", a)
print("b =", b)
# Out:
# Enter first number: 10
# Enter second number: 5
# After swapping:
# a = 5
# b = 10
